# %%
from sklearn.decomposition import PCA
import pandas as pd
import numpy as np
#df = pd.read_csv("https://raw.githubusercontent.com/mini-pw/2021Z-DataVisualizationTechniques/master/labs/data/Pokemon.csv", index_col=0, sep=",")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/2q/z8df08fx73b3vq941pty77xh0000gn/T/ipykernel_5897/488289194.py in <module>
#       3 import numpy as np
#       4 #df = pd.read_csv("https://raw.githubusercontent.com/mini-pw/2021Z-DataVisualizationTechniques/master/labs/data/Pokemon.csv", index_col=0, sep=",")
# ----> 5 df = pd.read_csv(mess_jan)
#
# NameError: name 'mess_jan' is not defined

# %%
df1 = pd.read_csv("mess_jan")
# Out:
#   File "/var/folders/2q/z8df08fx73b3vq941pty77xh0000gn/T/ipykernel_5897/1388405895.py", line 2
#     df["reactions"][4]
#     ^
# IndentationError: unexpected indent

# %%
df.to_csv("mess_jan1")

# %%
for i in range(df.shape[0]):
    if isinstance(df["content"][i],str) :
        df["content"][i]=df["content"][i].encode('latin').decode('utf8')
    if isinstance(df["sender_name"][i],str) :
        df["sender_name"][i]=df["sender_name"][i].encode('latin').decode('utf8')
df
# Out:
# /var/folders/2q/z8df08fx73b3vq941pty77xh0000gn/T/ipykernel_5897/3874270979.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["content"][i]=df["content"][i].encode('latin').decode('utf8')
# /var/folders/2q/z8df08fx73b3vq941pty77xh0000gn/T/ipykernel_5897/3874270979.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["sender_name"][i]=df["sender_name"][i].encode('latin').decode('utf8')
#           sender_name  timestamp_ms  \
# 0          Jan Szydło  1.639466e+09
# 1          Jan Szydło  1.639466e+09
# 2      Michał Mazuryk  1.639466e+09
# 3      Michał Mazuryk  1.639466e+09
# ...
